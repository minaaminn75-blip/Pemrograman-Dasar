# %% [markdown]
# <a href="https://colab.research.google.com/github/minaaminn75-blip/Pemrograman-Dasar/blob/main/percobaan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = "Hendi"
nama = "yasmin"

x = 11
b = 8

#c = x+b

print (x)
print (b)


#print (c)

"""


mahasiswa = ["jokoo", 202488, fslse, 198]
#print(mahasiswa)

#print("NIM :",mahasiswa [1], "tinggi badan, "mahasiswa[3])
"""
# Out:
#   File "/tmp/ipykernel_518/2595532748.py", line 15
#     """
#     ^
# _IncompleteInputError: incomplete input
