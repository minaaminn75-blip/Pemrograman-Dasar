# %% [markdown]
# <a href="https://colab.research.google.com/github/minaaminn75-blip/Pemrograman-Dasar/blob/main/Tugas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#latihan 1
tegangan_panel = 18
arus_panel = 6
jenis_sel = "Monocrystalline"

print(tegangan_panel)
print(arus_panel)
print(jenis_sel)
# Out:
# 18
# 6
# Monocrystalline

# %%
#latihan 2
jumlah_resistor = 10
kapasitas_kapasitor = 4.7
LED_aktif = True
nama_komponen = "transistor NPN"

print(jumlah_resistor)
print(kapasitas_kapasitor)
print(LED_aktif)
print(nama_komponen)
# Out:
# 10
# 4.7
# True
# transistor NPN

# %%
#latihan 3
nama_unit = "PLTS Nunukan"
jumlah_panel = 240
tegangan_keluaran = 48.5
sedang_beroperasi = True

print(nama_unit)
print(jumlah_panel)
print(tegangan_keluaran)
print(sedang_beroperasi)
# Out:
# PLTS Nunukan
# 240
# 48.5
# True

# %%
#latihan 4
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

print("Pembacaan pertama :", tegangan_harian[0])
print("Pembacaan terakhir :", tegangan_harian[-1])

tegangan_harian.append(220.0)
print("Data setelah ditambah:", tegangan_harian)

print("jumlah total data :", len(tegangan_harian))
# Out:
# Pembacaan pertama : 217.5
# Pembacaan terakhir : 216.9
# Data setelah ditambah: [217.5, 219.0, 220.3, 218.7, 221.1, 216.9, 220.0]
# jumlah total data : 7

# %%
#latihan 5
motor_listrik = {
    "nama": "Motor Induksi AC",
    "daya_kW": 15.0,
    "tegangan_V": 380,
    "rpm": 1450,
    "arus_A": 28.5,
    "frekuensi_Hz": 50,
    "faktor_daya": 0.85,
    "jumlah_fasa": 3,
    "kelas_isolasi": "F",
    "status_operasi": True
}

print("Nilai RPM awal:", motor_listrik["rpm"])

motor_listrik["rpm"] = 1500

print("Dictionary setelah diubah:")
print(motor_listrik)
# Out:
# Nilai RPM awal: 1450
# Dictionary setelah diubah:
# {'nama': 'Motor Induksi AC', 'daya_kW': 15.0, 'tegangan_V': 380, 'rpm': 1500, 'arus_A': 28.5, 'frekuensi_Hz': 50, 'faktor_daya': 0.85, 'jumlah_fasa': 3, 'kelas_isolasi': 'F', 'status_operasi': True}

# %%
#latihan 6
pembangkit = [
    {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"nama": "Unit-3", "kapasitas_MW:": 80, "status": "pemeliharaan"},
]

print("Nama unit kedua:", pembangkit[1]["nama"])

pembangkit[2]["status"] = "operasi"

unit_baru = {"nama": "Unit-4", "kapasitas_MW": 120, "status": "cadangan"}
pembangkit.append(unit_baru)

print("Data seluruh pembangkit:")
print(pembangkit)
# Out:
# Nama unit kedua: Unit-2
# Data seluruh pembangkit:
# [{'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'operasi'}, {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}, {'nama': 'Unit-3', 'kapasitas_MW:': 80, 'status': 'operasi'}, {'nama': 'Unit-4', 'kapasitas_MW': 120, 'status': 'cadangan'}]

# %% [markdown]
# To access specific keys in a dictionary, you use the key name inside square brackets `[]` after the dictionary variable. For example:
