# %% [markdown]
# <a href="https://colab.research.google.com/github/minaaminn75-blip/Pemrograman-Dasar/blob/main/Tugas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya

nama = "Mailaf Faiza Yasmin"
umur = "19"
jurusan = "Teknik Elektro"
prodi = "Teknologi Rekayasa Pembangkit Energi"
semester = "3"
matakuliah = "Pemerograman Dasar"
hobi = "membaca buku dan merakit lego"
tempat_tgl_lahir = "Batam, 6 Mei 2007"
asal_sekolah = "Man 1 Batam"
alamat_rumah = "perum Taman Jaya Asri blok C2/17, Buliang, Batu Aji, Batam"
status_lulus = False

print (nama)
print (umur)
print (jurusan)
print (prodi)
print (semester)
print (matakuliah)
print (hobi)
print (tempat_tgl_lahir)
print (asal_sekolah)
print (alamat_rumah)
print (status_lulus)
# Out:
# Mailaf Faiza Yasmin
# 19
# Teknik Elektro
# Teknologi Rekayasa Pembangkit Energi
# 3
# Pemerograman Dasar
# membaca buku dan merakit lego
# Batam, 6 Mei 2007
# Man 1 Batam
# perum Taman Jaya Asri blok C2/17, Buliang, Batu Aji, Batam
# False
