# %% [markdown]
# <a href="https://colab.research.google.com/github/minaaminn75-blip/Pemrograman-Dasar/blob/main/latihan%201%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 5
b = 20
c = 15

print ("hasilnya: ",c)
# Out:
# hasilnya:  15

# %%
# Biodata Saya

nama = "Mailaf Faiza Yasmin"
umur = "19"
jurusan = "Teknik Elektro"
prodi = "Teknologi Rekayasa Pembangkit Energi"
semester = "3"
matakuliah = "Pemerograman Dasar"
status_lulus = False

print (nama)
print (umur)
print (jurusan)
print (prodi)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# Mailaf Faiza Yasmin
# 19
# Teknik Elektro
# TRPE
# 3
# Pemerograman Dasar
# False
