# %% [markdown]
# <a href="https://colab.research.google.com/github/minaaminn75-blip/Pemrograman-Dasar/blob/main/pert%201%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya

nama = "Mailaf Faiza Yasmin"
umur = "19"
jurusan = "RPE"
semester = "3"
matakuliah = 'Pemerograman Dasar'
Status_lulus = False

print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (Status_lulus)
# Out:
# Mailaf Faiza Yasmin
# 19
# RPE
# 3
# Pemerograman Dasar
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3043/297280738.py in <cell line: 0>()
#      13 print (semester)
#      14 print (matakuliah)
# ---> 15 print (status_lulus)
#
# NameError: name 'status_lulus' is not defined
